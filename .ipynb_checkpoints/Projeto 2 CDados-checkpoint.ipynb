# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# ## Teste e predição de qualidade de vinhos brancos

# %% [markdown]
# ## Integrantes:

# %% [markdown]
# Alberto Carrera
#
# Arthur da Fonseca
#
# Gabriel Barbosa
#
# Rodrigo Gomes

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sb

# Para ter melhor print
from IPython.display import display

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\User\Desktop\INSPER\CIENCIA DE DADOS\Projeto-2-CDADOS

# %% [markdown]
# ### Convertendo o CSV em dataframe

# %% [markdown]
# Aqui estamos convertendo o csv em dataframe. Utilizamos o separador de casas decimais para que as virgulas fossem transformadas em ponto, para que assim o Python conseguisse ler os resultados de forma adequada.

# %%
dados1 = pd.read_csv('winequality-white.csv', sep=';')
dados1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Target variable

# %% [markdown]
# Sobre o dataframe mostrado acima, deve-se notar que no eixo 'x' temos os dados de vários aspectos (12 variaveis) de cada vinho (4898 vinhos), sendo a última coluna a mais importante pois ela mostra a qualidade dos vinhos, valor este que iremos prever com os nossos modelos ao fim desse projeto.

# %% [markdown]
# ### Apresentando o dataset

# %% [markdown]
# Portanto, nossa variável target será: "quality".
#
# Além dela, temos as seguintes variáveis (colunas):
#
#  * `fixed acidity`: acidez fixa do vinho, em mg/mL.
#  * `volatile acidity`: acidez volatil do vinho, em mg/mL.
#  * `citric acid`: quantidade de ácido cítrico do vinho, em mg/mL.
#  * `residual sugar`: açúcar residual do vinho, em mg/mL.
#  * `chlorides`: quantidade de cloretos, em mg/mL.
#  * `free sulfur dioxide`: quantidade de dióxido de enxofre livres, em p.p.m (partes por milhão).
#  * `total sulfur dioxide`: quantidade de dióxido de enxofre total, em p.p.m (partes por milhão).
#  * `density`: densidade, em g/cm³.
#  * `pH`: pH do vinho.
#  * `sulphates`: quantidade de sulfatos presentes no vinho, em p.p.m (partes por milhão).
#  * `alcohol`: porcentagem de álcool presente no vinho.

# %% [markdown]
# ### Limpando o dataset

# %% [markdown]
# O código realizado na célula debaixo demonstra que nenhum dos valores no Dataset eram nulos, concluindo nossa limpeza do Dataset, já que assim podemos analisar ele sem problemas

# %%
dados1.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# A partir do value counts, podemos concluir que o nosso Dataset pode ser analisado através da forma de classificador, pois os vinhos estão classificados em apenas 7 categorias, sendo elas de 3 a 9. Portanto, utilizar o metodo de classificador seria mais ideal, para que o resultado do nosso modelo de cálculo de probabilidade se encaixe dentro dessas 7 categorias.

# %%
dados1.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# ### Perguntas a serem respondidas

# %% [markdown]
# Para esse trabalho, temos como objetivo principal responder duas perguntas:
# * **Quais variáveis do dataset possuem correlações fortes entre elas e por quê?**
# * **Qual método de classificação e predição, dos três utilizados, foi o mais eficaz para prever a variável-target "quality" e quanto foi sua porcentagem de acerto?**

# %% [markdown]
# ### Análise do dataset

# %% [markdown]
# #### Análise de correlações entre variáveis

# %% [markdown]
#  Para fazer uma analise dos dados do nosso dataset, fizemos uma tabela de graficos de correlação entre todos os elementos da tabela, em que é possível ver que poucos dados possuem correlações fortes, já que a maioria deles estao bem distribuidos perante o gráfico.

# %%
import seaborn as sns
sns.pairplot(dados1, height=1.5);

# %% [markdown]
# Para fins de estética e melhor entendimento, plotamos o gráfico abaixo, conhecido como "heatmap" ou "mapa de calor", que mostra as correlações entre as colunas de forma mais prática e fácil de ser entendida.

# %%
plt.figure(figsize = (20,5))
dataplot = sb.heatmap(dados1.corr(), cmap="YlGnBu", annot=True)
plt.title('Heatmap da correlação')
plt.show()

# %% [markdown]
# ### Respondendo a primeira pergunta!

# %% [markdown]
# Das 144 correlações, 118 são menores do que 0.4.
# Ou seja, 75% das correlações são fracas.

# %% [markdown]
# ##### Correlações fortes

# %% [markdown]
# Temos 2 correlações fortes:
# * **residual sugar x density**
# * **alcohol x density**

# %% [markdown]
# As duas únicas correlações fortes merecem uma atenção e devem ser analisadas:

# %% [markdown]
# O açúcar residual do vinho influencia diretamente, como é de se esperar, na densidade do vinho, assim como sua porcentagem de álcool.

# %% [markdown]
# * Quanto maior é a quantidade de açúcar residual, maior é a densidade do vinho, são grandezas **diretamente proporcionais**
# * Quanto maior é  a quantidade de álcool, menor é a densidade do vinho, são grandezas **inversamente proporcionais**

# %% [markdown]
# ##### Correlações moderadas

# %% [markdown]
# Das correlações moderadas, é bastante interessante analisar a que compõe a nossa variável-target:
# * **alcohol x quality**

# %% [markdown]
# E podemos inferir que há uma correlação entre o álcool do vinho branco e sua qualidade, sendo essa associação positiva, grandezas **diretamente proporcionais**

# %% [markdown]
# ### Continuando a análise

# %% [markdown]
# Na célula abaixo fizemos a mesma coisa que nas duas de cima, porém na forma numérica. Isso permite analisarmos mais a correlação entre os dados do dataset e concluir que muitas delas são correlações negativas, que a grande maioria é fraca, já que poucas correlações resultaram em numeros acima de 0.4, o que seria considerado moderado.

# %%
dados1.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ### Classificando e prevendo a qualidade dos vinhos

# %% [markdown]
# Para fazer a simulação dos nossos dados, utilizamos o modelo Decision Tree. Optamos por dividir nosso dataset em 5 datasets, para que treinemos em quatro deles e realizemos o teste da probabilidade em apenas um último, sendo esse processo repetido 5 vezes. O resultado da célula abaixo são as porcentagens de acerto de cada uma dessas tentativas de se fazer a Decision Tree nos cinco datasets que foram divididos.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
cross_val_score(clf, dados1.iloc[:,:-1], dados1.quality, cv=5)
# Out:
# array([0.36938776, 0.37959184, 0.41326531, 0.4453524 , 0.42288049])

# %% [markdown]
# #### O que consiste o método Decision Tree? (Árvore de decisão)

# %% [markdown]
# O método Decision Tree tem o intuito de predizer um valor de uma varável target, aplicando e aprendendo regras de decisão simples inferidas a partir de um dataset.
# Uma árvore de dados pode ser vista como uma aproximação constante por partes.

# %% [markdown]
# A ideia é construir um procedimento de perguntas de sim ou não a partir de certas características/atributos (no caso as features), para obter o target, que pode ser categórico ou numérico.

# %% [markdown]
# ### Primeiro método de previsão e classificação - Decision Tree

# %% [markdown]
# #### Aplicando esse primeiro método no último dataset de teste

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dados1.iloc[:,:-1], dados1['quality'], test_size=0.4, random_state=0)
clf1 = DecisionTreeClassifier(random_state=0)
clf1.fit(X_train, y_train)
clf1.score(X_test, y_test)
# Out:
# 0.5637755102040817

# %% [markdown]
# Como plotado na célula anterior, podemos observar que através do método da Decision Tree obtivemos uma taxa de acerto equivalente à cerca de 56%

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf1, X_test, y_test)

# %% [markdown]
# O gráfico acima representa de maneira visual a quantidade de avaliações certas do nosso modelo para cada qualidade de vinho.
# * Como observado, a Decision Tree se destacou na predição de vinhos nota 6, uma vez que avaliou corretamente 543 de 844 desta categoria (representando uma taxa de 64% de acerto).
# * Além do mais, é curioso observar que dos vinhos que tinham nota 6 e foram avaliados erroneamente, 273 deles foram dados como notas 5 ou 7, ou seja, daquele total de 844, apenas 28 fugiram muito da realidade, o que mostra uma margem de erro pequena.
# * Outras avaliações que obtiveram destaque foram as de vinhos notas 5 e 7, que tiveram como índice de acerto 59% e 48%, respectivamente.
# * No quesito predições mal feitas, tivemos inúmeros vinhos também notas 5 ou 7 sendo avaliados como nota 6 (320 no total).
# * Além disso é importante destacar o caso dos que possuem nota 9. Por ser uma nota dificilmente alcançada, a quantidade desses vinhos no dataset era baixa e acabou que todos foram parar nos quatro primeiros datasets-teste, tanto é que verificamos isso na tabela ao perceber que na "True label" não há marcado nenhum vinho nota 9.

# %% [markdown]
# #### Plotando um histograma para a predição da qualidade de vinhos e comparar com o gráfico verdadeiro.

# %%
dados_previstos = clf1.predict(X_test)

plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.hist(dados_previstos, edgecolor='white', color='darkorange', density = True)
plt.title('Contagem dos dados previstos')
plt.ylabel('densidade')

plt.subplot(122)
plt.hist(dados1.quality, edgecolor='white', color='blue', density = True)
plt.title('Contagem real (eixo y)')
plt.ylabel('densidade')
# Out:
# Text(0, 0.5, 'densidade')

# %% [markdown]
# Podemos analisar que a densidade dos dois histogramas foi igual, o que era de se esperar, baseando-se no método Decision Tree.

# %% [markdown]
# ### Segundo método de previsão e classificação - Random Forest

# %% [markdown]
# #### O que consiste esse método?

# %% [markdown]
# O Random Forest Classifier é basicamente um conjunto de Decision Trees, onde ele ajusta várias árvores de decisão em subamostras para depois fazer a média com intuito de melhorar a predição e o sobreajuste de controle.

# %% [markdown]
# Seu nome explica muito bem o funcionamento do algoritmo, que irá criar muitas árvores de decisão, de maneira aleatória, formando o que podemos enxergar como uma floresta, onde cada árvore será utilizada na escolha do resultado final.

# %% [markdown]
# #### Aplicando esse primeiro método no último dataset de teste

# %%
from sklearn.ensemble import RandomForestClassifier

clf2 = RandomForestClassifier(max_depth=8, random_state=0)
clf2.fit(X_train, y_train)
clf2.score(X_test, y_test)
# Out:
# 0.576530612244898

# %% [markdown]
# Esse 0.57 representa a porcentagem de acertos obtidos através do método em questão. Ou seja, com Random Forest obtivemos uma taxa de 57% de acerto, o que representa uma melhora discreta em relação ao método anterior da Decision Tree.

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf2, X_test, y_test, labels = dados1['quality'].drop_duplicates().sort_values().to_list())

# %% [markdown]
# Acima, temos um gráfico bem visual para o método da Random Forest. Nele é muito importante destacar uma avaliação ainda melhor na categoria dos vinhos nota 6.
# * Antes de tudo é legal reparar que TODOS os vinhos nota 6 foram avaliados entre 5 a 7 (o que mostra certa proximidade com a realidade).
# * Agora falando apenas de acertos, o modelo teve desempenho positivo de 82% dessa categoria em questão.
# * Todavia é de suma importância destacar uma piora entre os vinhos de notas 5 e 7, que antes também havíam obtido resultados de destaque positivo.
# * No caso da Random Forest, a taxa de acertos dos vinhos nota 5 caiu para 53% (que apesar da queda permanece uma boa porcentagem) e os nota 7 tiveram uma redução dos acertos para 29%.
# * Por fim é importante dizer que como ambos os métodos até agora usaram a mesma base de dados tanto para teste, quanto para treino, a situação já descrita que prejudica a avaliação dos vinhos nota 9 permanece a mesma.

# %% [markdown]
# #### Plotando um histograma para a predição da qualidade de vinhos e comparar com o gráfico verdadeiro.

# %%
dados_previstos = clf2.predict(X_test)

plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.hist(dados_previstos, edgecolor='white', color='darkorange', density = True)
plt.title('Contagem dos dados previstos')
plt.ylabel('densidade')

plt.subplot(122)
plt.hist(dados1.quality, edgecolor='white', color='blue', density = True)
plt.title('Contagem real')
plt.ylabel('densidade')
# Out:
# Text(0, 0.5, 'densidade')

# %% [markdown]
# Podemos analisar nesses dois histogramas uma diferença nítida em relação ao obtido pelo método de Decision Tree:
# * A densidade entre eles é diferente, sendo a de vinhos com qualidade 6 muito maiores.
# * Nesse método, não houveram predições de qualidades nos extremos (3 e 9).
# * As predições ficaram centralizadas nesse método, variando de 5 a 7:
#     * Das 1960 predições, 1953 ficaram entre os números 5 e 7 (cerca de 99.64%)

# %% [markdown]
# ### Terceito método de previsão e classificação - K Nearest Neighbor

# %% [markdown]
# #### O que consiste esse método?

# %% [markdown]
# Neste algoritmo possuímos uma variável chamada de K, a qual é parte do nome do modelo e também o principal parâmetro a ser selecionado. Este parâmetro direcionará a quantidade de vizinhos (neighborn em inglês).

# %% [markdown]
# Em resumo, a sua classificação é feita do seguinte modo:

# %% [markdown]
# * Recebe um dado não classificado e mede a distância do novo dado em relação a cada um dos outros dados que já estão classificados;
#
# * Seleciona as K menores distâncias;
#
# * Verifica a(s) classe(s) dos dados que tiveram as K menores distâncias e contabiliza a quantidade de vezes que cada classe que apareceu;
#
# * Classifica esse novo dado como pertencente à classe que mais apareceu.

# %%
from sklearn.neighbors import KNeighborsClassifier

clf3 = KNeighborsClassifier(n_neighbors= 5)
clf3.fit(X_train, y_train)
clf3.score(X_test, y_test)
# Out:
# 0.4607142857142857

# %% [markdown]
# Como vemos acima, nosso método KNN obteve uma taxa de acerto de 46% (a mais baixa dentre todas as três), o que é explicável, pois esse método não necessita de dados de treinamento para se gerar o modelo. No caso de algoritmos que não necessitam de treinamento, resulta em um treinamento muito rápido e em um teste e validação lentos, momento o qual necessitamos estar bem atentos aos resultados gerados.

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf3, X_test, y_test, labels = dados1['quality'].drop_duplicates().sort_values().to_list())

# %% [markdown]
# Acima vemos o gráfico da quantidade de acertos para cada categoria que obtivemos com o método KNN (assim como feito para todos os demais métodos). Como já vimos no resultado, fica claro que o método KNN foi o menos eficiente entre todos os utilizados e isso reflete automaticamente na taxa de acerto para cada vinho.
# * Os vinhos nota 6, que se destacaram com grandes porcentagens de predições corretas, tiveream uma queda significativa: após obterem 64% de acerto com Decision Tree e 82% com Random Forest, a categoria viu sua taxa cair para 53% (porcentagem essa que ainda representa a maior do todo, porém mesmo assim demonstra significativa queda).
# * As demais categorias também tiveram uma queda na taxa de avaliações corretas e é válido destacar que o método KNN obteve recorde no número de vinhos nota 5 avaliados como nota 6: 380 no total (superando com sobras o 355 do método Decision Tree).
# * Assim como nos demais métodos, a avaliação dos vinhos nota 9 também foi comprometida por conta da baixa ocorrência dessa classificação.

# %% [markdown]
# #### Plotando um histograma para a predição da qualidade de vinhos e comparar com o gráfico verdadeiro.

# %%
dados_previstos = clf3.predict(X_test)

plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.hist(dados_previstos, edgecolor='white', color='darkorange', density = True)
plt.title('Contagem dos dados previstos')
plt.ylabel('densidade')

plt.subplot(122)
plt.hist(dados1.quality, edgecolor='white', color='blue', density = True)
plt.title('Contagem real')
plt.ylabel('densidade')
# Out:
# Text(0, 0.5, 'densidade')

# %% [markdown]
# Analisando esses dois últimos histogramas, podemos inferir que houve uma maior distribuição dos dados previstos, mas que as extremidades ainda foram excluídas, sem ocorrências de classificações 3 e 9.
# * É possivel inferir também que a densidade de ocorrências da classificação 7 é próxima, se não igual, que está em torno de 0.3.
# * A razão entre a densidade da classificação 6 com a densidade de classificação 5 é bem parecida nos dois gráficos:
#     * No modelo previsto, a razão é de 1.6875, já no real, é de 1.6.
#     * Com isso, podemos dizer que há uma semelhança na distribuição entre as duas classificações.

# %% [markdown]
# ### Conclusão:

# %% [markdown]
# ### Respondendo a segunda pergunta!

# %% [markdown]
# O método que teve a maior porcentagem de acerto foi o segundo método, o **Random Forest**, com **57.65%** de acerto.

# %% [markdown]
# Já o método com menor porcentagem de acerto foi o terceito, o **KNN**, com **46.07%** de acerto.

# %% [markdown]
# A classificação mais acertiva, dentre os três métodos de classificação e predição utilizados, foi a classificação de qualidade 6 no método **Random Forest**, com incríveis 82% de acerto!

# %% [markdown]
# As extremidades da nossa variável "quality", ou seja, as classificações 3 e 9, foram prejudicadas nos métodos de classificação por apresentarem um baixo índice de ocorrência no nosso dataset, o que tornou inviável a separação em datasets de treinos e testes.
