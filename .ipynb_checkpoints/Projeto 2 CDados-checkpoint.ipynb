# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# ## Teste e predição de qualidade de vinhos brancos

# %% [markdown]
# ## Integrantes:

# %% [markdown]
# Alberto Carrera
#
# Arthur da Fonseca
#
# Gabriel Barbosa
#
# Rodrigo Gomes

# %%
# %matplotlib inline
import pandas as pd
import os

# Para ter melhor print
from IPython.display import display

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\User\Desktop\INSPER\CIENCIA DE DADOS\Projeto-2-CDADOS

# %%
dados = pd.read_excel('winequality-white.xls')
dados.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide    density    pH  sulphates  \
# ...

# %% [markdown]
# ### Limpando o datasheet de valores exdrúxulos

# %% [markdown]
# ##### Density

# %%
#ARREDONDANDO OS VALORES DA COLUNA 'DENSITY' QUE SÃO MAIORES DO QUE 1, POIS O EXCEL 
#ENTENDE O 1.000056 COMO UM NÚMERO NATURAL, NÃO RACIONAL.

#SE FIZERMOS A TROCA POR ',' O PYTHON NÃO ENTENDERIA, PORTANTO OPTAMOS PELO ARREDONDAMENTO.
#OS NÚMEROS VARIAVAM MENOS DE 4% PARA CIMA DE UM, COM O NÚMERO MÁXIMO DE 1.03898.
#É POSSÍVEL VER NO DATASHEET ACIMA, NA LINHA 7.
#PORTANTO ACHAMOS VÁLIDA TAL SIMPLIFICAÇÃO.

def arredonda(x):
    if x > 1000:
        return 1
    else:
        return x

dados.density = dados.density.apply(arredonda)
dados.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#PODEMOS VER QUE FUNCIONOU PELA LINHA 7, QUE AGORA ESTÁ COMO 1.000, OU SEJA, 1.
